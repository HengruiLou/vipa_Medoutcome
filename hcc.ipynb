# %%
import openslide
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
import tqdm

# %%
slides = glob.glob('/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/*.svs')
slides
# Out:
# ['/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201121868_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201122039_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201122061_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201122287_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201122320_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201122324_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201122326_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201123052_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201124026_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201124041_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201124487_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201125276_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201125292_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201125506_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201125513_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201125524_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201125542_HE_10.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201134570_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201134791_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201134999_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201158340_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201158741_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201158804_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201200222_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201200246_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201200453_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201200462_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201200676_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201201111_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201202725_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201202734_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201203490_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201219735_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201219986_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201220752_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201221046_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201221648_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201222784_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201224425_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201224669_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201224965_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201224973_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201224993_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201225740_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201226070_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201226389_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201226863_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201251024_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201251325_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201251654_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201252572_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201253114_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201253386_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201254799_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201254855_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201129900_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201203782_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201210076_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201228001_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201246360_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201255428_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201259463_HE_16.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201300212_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201300221_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201300420_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201300861_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201300885_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201300946_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201301196_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201301690_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201301951_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341508_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341579_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341589_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342037_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342102_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342367_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342594_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342598_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342635_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342643_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342872_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342920_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201342945_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201343126_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201343401_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201343486_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201349873_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201350245_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201350537_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201350549_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201350560_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201350861_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201350910_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201351227_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201359561_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360062_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360072_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360074_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360083_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360140_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360335_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360341_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360390_HE_11.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360404_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360633_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360910_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201360920_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201361256_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201361524_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201361591_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201450345_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201450650_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201450756_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201451379_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201452972_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201453255_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201453256_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201453285_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201454259_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201519509_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201520757_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201523964_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201524304_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201524588_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201524599_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201524940_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201525279_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201525993_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201526012_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201527041_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201550810_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201551277_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201551817_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201552556_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201552882_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201553937_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201554270_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201555266_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201556651_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201556661_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201557360_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201557783_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201558400_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201558410_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201626763_HE_11.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201628554_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201629257_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201631150_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201631157_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201631170_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201631428_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201631473_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201634065_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201634082_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201634447_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201635166_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201635967_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201234564_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201234574_HE_15.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201235577_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201235630_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201235872_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201236201_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201236386_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201237232_HE_10.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201237787_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201238046_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201347205_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201347230_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201347243_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201347259_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201347540_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201347849_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201348130_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201348173_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201348235_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201348409_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327897_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327900_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327980_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201328266_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201328887_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201329192_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201329484_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201329516_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201329863_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201329892_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201125748_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201126442_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201126453_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201126687_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201126925_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201127398_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201128090_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201128095_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201128097_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201128744_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201128768_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201128993_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201129013_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201129215_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201129442_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201211708_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201211708_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201212572_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201213135_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201213152_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201214436_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201214443_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201214631_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201259490_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201259493_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201259733_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201259839_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201260112_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201260567_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201260592_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201260658_HE_8.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201260929_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201260933_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201261432_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201261754_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201261756_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201262013_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201356563_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201356883_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201356891_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201357144_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201357156_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201357198_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201357494_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201357765_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201357767_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201365915_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201365931_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366123_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366130_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366152_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366184_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366184_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366191_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366354_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366440_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201461842_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201461850_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201462891_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201463908_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201466144_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201467164_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201467173_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201467224_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201467551_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201468671_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201470152_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201470485_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201664137_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201664941_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201665691_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201666403_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201666750_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201666775_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201667578_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201669909_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201670272_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201670287_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201670977_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201671013_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201672474_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201563036_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201564293_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201564313_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201564711_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201564722_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201565536_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201566579_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201566581_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201567949_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201569059_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201570891_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201539323_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201539357_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201539376_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201539812_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201540054_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201540158_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201540446_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201541410_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201541796_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201541831_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201542116_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201542169_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201545326_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201545330_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201243746_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201243749_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201243809_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201244379_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201245489_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201245769_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201246279_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201246352_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201331815_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201331827_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201332081_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201332110_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201332125_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201332413_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201332987_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201332997_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333022_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333225_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333233_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333285_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333528_HE_11.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333548_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333851_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333856_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201343691_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201343702_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201343960_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201343995_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201344200_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201344215_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201344440_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201345099_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201345330_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201345352_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201345568_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201345580_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201361592_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201361780_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201361791_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201361857_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201362096_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201362382_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201362995_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201363541_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201363601_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201417403_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201418277_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201418604_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201419249_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201419275_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201419941_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201420224_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201420667_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201423297_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201424487_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201424583_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201424802_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201427508_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201427534_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201473838_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201473864_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201474201_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201476167_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201476888_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201476900_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201477242_HE_8.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201477554_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201478207_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201478861_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201479419_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201479808_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201500044_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201500089_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201500319_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201643972_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201646625_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201648412_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201648414_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201648798_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201649380_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201649384_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201649399_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201649435_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201652137_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201652519_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201654267_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201655270_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201655292_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201655307_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201656223_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201576538_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201578293_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201579047_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201579328_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201581029_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201581048_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201581362_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201581382_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201582760_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201583088_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201583373_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201583414_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201361592_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201363843_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201454597_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201461821_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201473180_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201531944_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201531986_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201532000_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201533070_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201533408_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201533731_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201533830_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201534741_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201535422_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201536233_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201673989_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201677092_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201677536_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201678204_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201679006_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201680866_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201681880_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201682604_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201203799_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201204056_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201204554_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201205137_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201205141_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201205352_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201205369_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201205566_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201306014_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201306186_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201306413_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201306767_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201307200_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201307217_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201307691_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201307943_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201308152_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201427875_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201428889_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201429858_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201433005_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201433387_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201433764_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201435114_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201447285_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201447387_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201447602_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201448362_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201449359_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201449380_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201449649_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201449674_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201450054_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201262612_HE_11.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201262829_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201262889_HE_8.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201263408_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201263421_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201263711_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201264029_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201264760_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201264765_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201265286_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201265313_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201265533_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201266126_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201266389_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201266646_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201267171_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201656237_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201656564_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201657507_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201657722_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201658799_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201659050_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201659063_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201659374_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201660497_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201661248_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201661258_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201661303_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201661672_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201662683_HE_13.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201663423_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201353775_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201353838_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201354354_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201354878_HE_10.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201355166_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201355205_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201355210_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201355521_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201355575_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201355816_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201356004_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201356020_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201356026_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201363856_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201364470_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201364524_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201364793_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201364796_HE_8.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201364954_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201365596_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201365622_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201365818_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201365822_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201365838_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201129940_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201129990_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201130149_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201130407_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201130413_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201130899_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201131562_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201132037_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201132072_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201132264_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201132369_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201132372_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201133210_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201133658_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201134341_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201228046_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201229162_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201229165_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201230074_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201230108_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201230611_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201230899_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201230902_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201232410_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201233748_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201234029_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201234031_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201333907_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201335906_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201336185_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201336187_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201336816_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201337903_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201338679_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201340111_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201340771_HE_8.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341020_HE_II4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341023_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341220_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341247_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341263_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201341337_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201348471_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201348734_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201349069_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201349322_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201349589_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201349612_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201349620_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201349624_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201349645_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201471112_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201471203_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201471530_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201471593_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201471864_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201471867_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201472201_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201472230_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201472447_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201473151_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201500337_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201502345_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201506001_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201506321_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201507019_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201507080_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201508028_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201508058_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201513936_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201514617_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201514922_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201517427_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201519117_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201519451_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201558458_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201560176_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201560185_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201560207_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201560526_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201561601_HE_null.svs',
# ...
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201549855_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201536253_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201536545_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201536552_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201536866_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201536899_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201536902_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201536981_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201537257_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201537305_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201538002_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201538047_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201538083_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201636348_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201636377_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201636724_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201636762_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201639279_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201639605_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201639936_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201640645_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201641757_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201642125_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201643275_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201643595_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201346714_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201346737_HE_10.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201346781_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201346784_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201346963_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201346982_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201346984_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201347184_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201214990_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201214996_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201215739_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201216810_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201216872_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201218007_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201218861_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201219436_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201219695_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366693_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201366698_HE_8.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201367033_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201400310_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201401636_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201404940_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201405497_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201408055_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201411567_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201412203_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201412578_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201413101_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201414081_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201414398_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201416393_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201416762_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201454999_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201455987_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201456019_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201456682_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201456993_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201457029_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201458010_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201459457_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201459771_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201527467_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201527762_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201528147_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201528519_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201528863_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201529174_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201530277_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201530605_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201530971_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201531258_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201531938_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201584438_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201602838_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201615651_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201619281_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201619323_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201621404_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201624208_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201624215_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201624287_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201625693_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201626041_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201302616_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201302660_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201303136_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201303826_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201303889_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201304350_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201304617_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201304800_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201357783_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201358012_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201358035_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201358328_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201358341_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201358604_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201358610_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201358635_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201359129_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201256011_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201256272_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201257226_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201257440_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201257755_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201258580_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201259210_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201259222_HE_8.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201683281_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201683970_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201683984_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201684010_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201684401_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201685089_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201685093_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201685122_HE_11.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201686187_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201687002_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201687613_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201687654_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201538369_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201545706_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201576225_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201584115_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201626362_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201673660_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201246656_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201246933_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201247237_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201247240_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201247868_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201249603_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201250117_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201250411_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201250720_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201250979_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201571150_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201572286_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201572587_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201573675_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201574709_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201575131_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201575137_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201575487_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201238187_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201239590_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201240769_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201240936_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201241039_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201242099_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201242105_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201242702_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201243563_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201205585_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201205660_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201205911_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201206186_HE_7.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201206423_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201208192_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201208486_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201209867_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201209867_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201209881_HE_1.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201302208_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201305258_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327882_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201331815_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201346227_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201348432_HE_null.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201351446_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201262611_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201527377_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201308626_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201326175_HE_6.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201326468_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201326716_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327038_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327386_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327622_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327626_HE_4.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201327633_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201351719_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201351993_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201352026_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201352038_HE_9.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201352885_HE_11.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201353123_HE_5.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201353423_HE_2.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201353495_HE_3.svs',
#  '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201353756_HE_4.svs']

# %%
import concurrent.futures
from tqdm import tqdm
from multiprocessing import Pool, Pipe, freeze_support

#=============================================================#
# 接口                                                        #
#-------------------------------------------------------------#
#   multi_process_exec 多进程执行                             #
#   multi_thread_exec  多线程执行                             #
#-------------------------------------------------------------#
# 参数：                                                      #
#   f         (function): 批量执行的函数                      #
#   args_mat  (list)    : 批量执行的参数                      #
#   pool_size (int)     : 进程/线程池的大小                   #
#   desc      (str)     : 进度条的描述文字                    #
#-------------------------------------------------------------#
# 例子：                                                      #
# >>> def Pow(a,n):        ← 定义一个函数（可以有多个参数）   #
# ...     return a**n                                         #
# >>>                                                         #
# >>> args_mat=[[2,1],     ← 批量计算 Pow(2,1)                #
# ...           [2,2],                Pow(2,2)                #
# ...           [2,3],                Pow(2,3)                #
# ...           [2,4],                Pow(2,4)                #
# ...           [2,5],                Pow(2,5)                #
# ...           [2,6]]                Pow(2,6)                #
# >>>                                                         #
# >>> results=multi_thread_exec(Pow,args_mat,desc='计算中')   #
# 计算中: 100%|█████████████| 6/6 [00:00<00:00, 20610.83it/s] #
# >>>                                                         #
# >>> print(results)                                          #
# [2, 4, 8, 16, 32, 64]                                       #
#-------------------------------------------------------------#

ToBatch = lambda arr, size: [arr[i * size:(i + 1) * size] for i in range((size - 1 + len(arr)) // size)]


def batch_exec(f, args_batch, w):
    results = []
    for i, args in enumerate(args_batch):
        try:
            if isinstance(args, (list, tuple, dict)):
                ans = f(*args)
            else:
                ans = f(args)
            results.append(ans)
        except Exception as e:
            print(e)
            results.append(None)
        w.send(1)
    return results


def multi_process_exec(f, args_mat, pool_size=5, desc=None):
    if len(args_mat) == 0: return []
    batch_size = max(1, int(len(args_mat) / 4 / pool_size))
    results = []
    args_batches = ToBatch(args_mat, batch_size)
    with tqdm(total=len(args_mat), desc=desc) as pbar:
        with Pool(processes=pool_size) as pool:
            r, w = Pipe(duplex=False)
            pool_rets = []
            for i, args_batch in enumerate(args_batches):
                pool_rets.append(pool.apply_async(batch_exec, (f, args_batch, w)))
            cnt = 0
            while cnt < len(args_mat):
                try:
                    msg = r.recv()
                    pbar.update(1)
                    cnt += 1
                except EOFError:
                    print('EOFError')
                    break
            for ret in pool_rets:
                for r in ret.get():
                    results.append(r)
    return results


def multi_thread_exec(f, args_mat, pool_size=5, desc=None):
    if len(args_mat) == 0: return []
    results = [None for _ in range(len(args_mat))]
    with tqdm(total=len(args_mat), desc=desc) as pbar:
        with concurrent.futures.ThreadPoolExecutor(max_workers=pool_size) as executor:
            futures = {executor.submit(f, *args): i for i, args in enumerate(args_mat)}
            for future in concurrent.futures.as_completed(futures):
                i = futures[future]
                ret = future.result()
                results[i] = ret
                pbar.update(1)
    return results

# %%
import time
import xml.dom.minidom as dom
from itertools import permutations

import torch
import torch.nn as nn


def read_points_from_xml(liver_name, scale=1,
                         xml_path='/mnt/datasets/medical/yxt/CAMELYON16/training/lesion_annotations/', dataset=''):
    if dataset == '':
        if 'HCC' in xml_path:
            dataset = 'HCC'
        elif 'CAMELYON16' in xml_path:
            dataset = 'CAMELYON16'
        elif 'TCGA' in xml_path:
            dataset = 'TCGA'

    if dataset == 'HCC':
        xml = dom.parse(xml_path + liver_name)
        tag_name = 'Annotation'
        point_name = 'Coordinate'
        x_name = 'X'
        y_name = 'Y'
    elif dataset == 'CAMELYON16':
        xml = dom.parse(xml_path + liver_name)
        tag_name = 'Annotation'
        point_name = 'Coordinate'
        x_name = 'X'
        y_name = 'Y'
    elif dataset == 'TCGA':
        xml = dom.parse(xml_path + liver_name)
        tag_name = 'Region'
        point_name = 'Vertex'
        x_name = 'X'
        y_name = 'Y'
    anno_list = xml.documentElement.getElementsByTagName(tag_name)
    polygons = []
    for anno in anno_list:
        polygons.append([])
        for point in anno.getElementsByTagName(point_name):
            x = int(float(point.getAttribute(x_name)))
            y = int(float(point.getAttribute(y_name)))
            polygons[-1].append([x // scale, y // scale])
    return polygons

# %%
def Pow(a, n):
    return a ** n


args_mat = [[2, 4], [3, 2], [4, 5]]
results = multi_process_exec(Pow, args_mat, desc='计算中')
print(results)

# %%
def save_thumb(slide):
    code = slide.split('/')[-1].split('.')[-2]
    s = openslide.open_slide(slide)
    if (s.level_count < 3):
        return
    size = s.level_dimensions[2]
    img = np.array(s.read_region((0, 0), 2, size).convert('RGB'))
    samples = np.array(s.level_downsamples, dtype=np.int32)
    if samples[2] == 16:
        img_reshape = cv2.resize(img, (size[0] // 4, size[1] // 4))
    elif samples[2] == 32:
        img_reshape = cv2.resize(img, (size[0] // 2, size[1] // 2))
    cv2.imwrite(f"/mnt/datasets/medical/lhm/liverWSI/gnn_1/{code}.png", img_reshape)


multi_process_exec(save_thumb, slides, 64, desc='processing')

# %%
name = "201202725_HE_4"
img = test1_reshape
polygons = read_points_from_xml(liver_name=f'{name}.xml',
                                xml_path="/mnt/datasets/medical/yxt/liverWSI/Hepatoma_2_5_years_800/", scale=64,
                                dataset='HCC')
mask = np.zeros(img.shape[:2], dtype=np.int8)
for index, p in enumerate(polygons):
    polygons[index] = np.array(p, dtype=np.int32)
cv2.polylines(mask, polygons, True, 255)
cv2.fillPoly(mask, polygons, 255)
plt.subplot(1, 2, 1)
plt.imshow(mask)
plt.subplot(1, 2, 2)
plt.imshow(img)
plt.show()

# %%
# def convert_numpy_img_to_superpixel_graph(img, polygons, code, slic_kwargs={}):
#     height = img.shape[0]
#     width = img.shape[1]
#     n = img.shape[0] * img.shape[1] // 1024
#     segments = slic(img, n_segments=n, compactness=20, slic_zero=True, start_label=0, **slic_kwargs)
#     np.save(f"/mnt/datasets/medical/lhm/liverWSI/gnn_1_seg/{code}.npy", segments)
#     num_of_nodes = np.max(segments) + 1
#     nodes = {node: {"rgb_list": []} for node in range(num_of_nodes)}
#     # get rgb values and positions
#     for y in range(height):
#         for x in range(width):
#             node = segments[y, x]
#             rgb = img[y, x, :]
#             nodes[node]["rgb_list"].append(rgb)
#     for node in nodes:
#         nodes[node]["rgb_list"] = np.stack(nodes[node]["rgb_list"])
#     G = nx.Graph()
#     # compute node positions
#     segments_ids = np.unique(segments)
#     pos = np.array([np.mean(np.nonzero(segments == i), axis=1) for i in segments_ids])
#     pos = pos.astype(int)
#     #pos[0]为height_y pos[1]为width_x
#     for node in nodes:
#         feature = nodes[node]['rgb_list'][:1024]
#         if len(feature) < 1024:
#             feature = np.pad(feature, ((0, 1024 - len(feature)), (0, 0)), 'edge')
#         for p in polygons:
#             p = np.array(p, dtype=np.int32)
#             label = cv2.pointPolygonTest(p, (int(pos[node][1] * 8), int(pos[node][0] * 8)), True) > 0
#         G.add_node(node, features=feature, label=(2 if label else 1))
#     # add edges
#     vs_right = np.vstack([segments[:, :-1].ravel(), segments[:, 1:].ravel()])
#     vs_below = np.vstack([segments[:-1, :].ravel(), segments[1:, :].ravel()])
#     bneighbors = np.unique(np.hstack([vs_right, vs_below]), axis=1)
#     for i in range(bneighbors.shape[1]):
#         if bneighbors[0, i] != bneighbors[1, i]:
#             G.add_edge(bneighbors[0, i], bneighbors[1, i])
#     # add self loops
#     for node in nodes:
#         G.add_edge(node, node)
# 
#     # get edge_index
#     m = len(G.edges)
#     edge_index = np.zeros([2 * m, 2]).astype(np.int64)
#     for e, (s, t) in enumerate(G.edges):
#         edge_index[e, 0] = s
#         edge_index[e, 1] = t
#         edge_index[m + e, 0] = t
#         edge_index[m + e, 1] = s
# 
#     # get features
#     # num_of_nodes = len(nodes)
#     num_of_features = 1024
#     x = np.zeros([num_of_nodes, num_of_features, 3]).astype(np.float32)
#     y = np.zeros(num_of_nodes).astype(np.float32)
#     coord = dict({})
#     for node in G.nodes:
#         x[node] = G.nodes[node]["features"]
#         y[node] = G.nodes[node]["label"]
#     return x, edge_index, pos, y

# %%
import multiprocessing
import os
import time
from itertools import repeat

import networkx as nx
import numpy as np
import torch
from skimage.segmentation import slic, mark_boundaries
from torch_geometric.data import Data

# tqdm for progress bar
from tqdm.auto import tqdm


def convert_numpy_img_to_superpixel_graph(img, polygons, code, slic_kwargs={}):
    height = img.shape[0]
    width = img.shape[1]
    n = 1024
    hsv_image = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    lower_white = np.array([0, 0, 255 - 15])  # 假设threshold是一个你选择的值
    upper_white = np.array([180, 255, 255])
    mask = 255 - cv2.inRange(hsv_image, lower_white, upper_white)
    kernel = np.ones((10, 10), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    mask = cv2.erode(mask, kernel, iterations=1)
    mask = mask / 255
    segments = slic(img, n_segments=n, slic_zero=True, compactness=10, start_label=0,
                    enforce_connectivity=True, convert2lab=True, sigma=0.7,
                    mask=mask, **slic_kwargs)

    np.save(f"/home/lhm/mnt/medical/lhm/liverWSI/gnn_1_seg/{code}.npy", segments)
    num_of_nodes = np.max(segments) + 1
    nodes = {node: {"rgb_list": [], "r": [], "g": [], "b": [], } for node in range(num_of_nodes)}
    # get rgb values and positions
    for y in range(height):
        for x in range(width):
            node = segments[y, x]
            if node < 0:
                continue
            rgb = img[y, x, :]
            nodes[node]["r"].append(rgb[2])
            nodes[node]["g"].append(rgb[1])
            nodes[node]["b"].append(rgb[0])
    for node in nodes:
        r_bin = np.bincount(nodes[node]["r"])
        r_bin = np.pad(r_bin, (0, 256 - len(r_bin)), 'constant', constant_values=(0, 0))
        g_bin = np.bincount(nodes[node]["g"])
        g_bin = np.pad(g_bin, (0, 256 - len(g_bin)), 'constant', constant_values=(0, 0))
        b_bin = np.bincount(nodes[node]["b"])
        b_bin = np.pad(b_bin, (0, 256 - len(b_bin)), 'constant', constant_values=(0, 0))
        nodes[node]["rgb_list"] = np.stack([r_bin, g_bin, b_bin]).ravel()
    G = nx.Graph()
    # compute node positions
    segments_ids = np.unique(segments)
    pos = np.array([np.mean(np.nonzero(segments == i), axis=1) for i in segments_ids])
    pos = pos.astype(int)
    #pos[0]为height_y pos[1]为width_x
    for node in nodes:
        feature = nodes[node]['rgb_list']
        label = 0
        for p in polygons:
            p = np.array(p, dtype=np.int32)
            label = cv2.pointPolygonTest(p, (int(pos[node][1]), int(pos[node][0])), True) > 0
        G.add_node(node, features=feature, label=label)
    # add edges
    vs_right = np.vstack([segments[:, :-1].ravel(), segments[:, 1:].ravel()])
    vs_below = np.vstack([segments[:-1, :].ravel(), segments[1:, :].ravel()])
    bneighbors = np.unique(np.hstack([vs_right, vs_below]), axis=1)
    for i in range(bneighbors.shape[1]):
        if bneighbors[0, i] == -1 or bneighbors[1, i] == -1:
            continue
        if bneighbors[0, i] != bneighbors[1, i]:
            G.add_edge(bneighbors[0, i], bneighbors[1, i])
    # add self loops
    for node in nodes:
        G.add_edge(node, node)

    # get edge_index
    m = len(G.edges)
    edge_index = np.zeros([2 * m, 2]).astype(np.int64)
    for e, (s, t) in enumerate(G.edges):
        edge_index[e, 0] = s
        edge_index[e, 1] = t
        edge_index[m + e, 0] = t
        edge_index[m + e, 1] = s

    # get features
    # num_of_nodes = len(nodes)
    num_of_features = 768
    x = np.zeros([num_of_nodes, num_of_features]).astype(np.float32)
    y = np.zeros(num_of_nodes).astype(np.float32)
    for node in G.nodes:
        x[node] = G.nodes[node]["features"]
        y[node] = G.nodes[node]["label"]
    return x, edge_index, pos, y

# %%
# img = cv2.imread('/nfs3/lhm/HCC/gnn_1/201357767_HE_5.png')
# name = i.split('/')[-1].split('.')[0]
# polygons = read_points_from_xml(liver_name= f'{name}.xml',scale=8,xml_path='/medical-data/yxt/liverWSI/Hepatoma_2_5_years_800/',dataset='HCC')
# x, edge_index, pos, y = convert_numpy_img_to_superpixel_graph(img,polygons)

# %%
def process_img(i):
    img = cv2.imread(i)
    name = i.split('/')[-1].split('.')[0]
    polygons = read_points_from_xml(liver_name=f'{name}.xml', scale=64,
                                    xml_path='/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/',
                                    dataset='HCC')
    x, edge_index, pos, y = convert_numpy_img_to_superpixel_graph(img, polygons, name)
    res = dict({})
    res['x'] = x
    res['edge'] = edge_index
    res['pos'] = pos
    res['y'] = y
    res['code'] = name
    np.save(f'/home/lhm/mnt/medical/lhm/liverWSI/gnn_1/{name}.npy', res, allow_pickle=True)


process_img('/home/lhm/mnt/medical/lhm/liverWSI/gnn_1/201122061_HE_1.png')

# %%
args_mat = glob.glob('/home/lhm/mnt/medical/lhm/liverWSI/gnn_1/*.png')
multi_process_exec(process_img, args_mat, 24, desc='processing')
# Out:
# processing:   0%|          | 0/812 [00:00<?, ?it/s]
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# [Errno 2] No such file or directory: '/home/lhm/mnt/medical/yxt/liverWSI/Hepatoma_2_5_years_800/201355521_HE_1.xml'
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# /home/lhm/miniconda3/envs/pytorch/lib/python3.9/site-packages/scipy/cluster/vq.py:602: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
a = np.load('/home/lhm/mnt/medical/lhm/liverWSI/gnn_1/201122061_HE_1.npy',allow_pickle=True).item()
a['x'].shape
# Out:
# (1024, 768)
